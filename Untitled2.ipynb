# %%
from dask.distributed import Client

# Start a Dask client
client = Client()

# Print the Dashboard URL
print(f"Dask dashboard is running at {client.dashboard_link}")

# ... rest of your code ...
# Out:
# Dask dashboard is running at http://127.0.0.1:8787/status
# 2024-01-10 04:37:48,058 - bokeh.server.protocol_handler - ERROR - error handling message
#  message: Message 'PULL-DOC-REQ' content: {}
#  error: SerializationError("can't serialize <class 'function'>")
# Traceback (most recent call last):
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/server/protocol_handler.py", line 97, in handle
#     work = await handler(message, connection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/server/session.py", line 257, in _handle_pull
#     return connection.protocol.create('PULL-DOC-REPLY', message.header['msgid'], self.document)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/protocol/__init__.py", line 131, in create
#     return self._messages[msgtype].create(*args, **kwargs)  # type: ignore [attr-defined]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/protocol/messages/pull_doc_reply.py", line 82, in create
#     content = PullDoc(doc=document.to_json())
#                           ^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/document/document.py", line 752, in to_json
#     roots = serializer.encode(self._roots)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 277, in _encode
#     return self._encode_list(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in _encode_list
#     return [self.encode(item) for item in obj]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in <listcomp>
#     return [self.encode(item) for item in obj]
#             ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 261, in _encode
#     return obj.to_serializable(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/model/model.py", line 525, in to_serializable
#     super_rep = super().to_serializable(serializer)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in to_serializable
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in <dictcomp>
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                        ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 277, in _encode
#     return self._encode_list(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in _encode_list
#     return [self.encode(item) for item in obj]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in <listcomp>
#     return [self.encode(item) for item in obj]
#             ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 261, in _encode
#     return obj.to_serializable(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/model/model.py", line 525, in to_serializable
#     super_rep = super().to_serializable(serializer)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in to_serializable
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in <dictcomp>
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                        ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 261, in _encode
#     return obj.to_serializable(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/model/model.py", line 525, in to_serializable
#     super_rep = super().to_serializable(serializer)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in to_serializable
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in <dictcomp>
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                        ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 277, in _encode
#     return self._encode_list(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in _encode_list
#     return [self.encode(item) for item in obj]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in <listcomp>
#     return [self.encode(item) for item in obj]
#             ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 261, in _encode
#     return obj.to_serializable(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/model/model.py", line 525, in to_serializable
#     super_rep = super().to_serializable(serializer)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in to_serializable
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in <dictcomp>
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                        ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 261, in _encode
#     return obj.to_serializable(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/model/model.py", line 525, in to_serializable
#     super_rep = super().to_serializable(serializer)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in to_serializable
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/has_props.py", line 413, in <dictcomp>
#     attributes = {key: serializer.encode(val) for key, val in properties.items()}
#                        ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 281, in _encode
#     return self._encode_dict(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 340, in _encode_dict
#     entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 340, in <listcomp>
#     entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#                                 ^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 277, in _encode
#     return self._encode_list(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in _encode_list
#     return [self.encode(item) for item in obj]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 323, in <listcomp>
#     return [self.encode(item) for item in obj]
#             ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 252, in encode
#     return self._encode(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 296, in _encode
#     return self._encode_other(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 469, in _encode_other
#     self.error(f"can't serialize {type(obj)}")
#   File "/home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/bokeh/core/serialization.py", line 472, in error
#     raise SerializationError(message)
# bokeh.core.serialization.SerializationError: can't serialize <class 'function'>

# %%
import dask.array as da
from dask.distributed import Client


def heavy_computation(x):
    # Simulate heavy computation
    return x * x - x + 1

# Generate large random Dask arrays
array_size = 1000000  # Adjust this size based on your system's capability
dask_arrays = [da.random.random((array_size, array_size), chunks=(1000, 1000)) for _ in range(10)]

# Perform computation on these arrays
results = [da.apply_gufunc(heavy_computation, "()->()", x).compute() for x in dask_arrays]

# Remember to close the client when done
client.close()
# Out:
# /home/mikolaj/VIRTUAL/ENV1/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39015 instead
#   warnings.warn(

# %%
import numpy as np

# %%
a = np.ones((10,10, 3))
b = np.array([1,2,3])
np.dot(a,b)
# Out:
# array([[6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.],
#        [6., 6., 6., 6., 6., 6., 6., 6., 6., 6.]])

# %% [markdown]
# a = np.ones((3,10,10))
